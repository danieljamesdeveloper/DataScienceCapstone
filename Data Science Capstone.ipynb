# %% [markdown]
# # Data Science Capstone Project

# %% [markdown]
# ## Introduction
# This data science project is part of the data science program offered by IBM. It is the final step in the 10 course program. This project will utilize location data to solve a data science challenge.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
